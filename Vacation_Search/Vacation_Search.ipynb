# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np
# Import API key
from config import G_API_Key


# Configure gmaps API key
gmaps.configure(api_key=G_API_Key)

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("../Weather_Database/WeatherPy_Database.csv", index_col=False)

# %%
city_data_df
# Out:
#      Unnamed: 0          City Country      Lat       Lng  Max Temp  Humidity  \
# 0             0         Kapaa      US  22.0752 -159.3190     80.58        81
# 1             1  Punta Arenas      CL -53.1500  -70.9167     42.12        93
# 2             2     Cape Town      ZA -33.9258   18.4232     58.91        73
# 3             3       Aksarka      RU  66.5606   67.7975      3.36        95
# 4             4         Hobyo      SO   5.3505   48.5268     83.25        72
# ..          ...           ...     ...      ...       ...       ...       ...
# 691         691        Mizdah      LY  31.4451   12.9801     55.94        56
# 692         692     Kysyl-Syr      RU  63.8986  122.7617     26.56        77
# 693         693   Honningsvag      NO  70.9821   25.9704     38.95        87
# 694         694      Takoradi      GH   4.8845   -1.7554     79.54        88
# 695         695         Floro      NO  61.5996    5.0328     46.36        76
#
#      Cloudiness  Wind Speed      Current Description
# 0            59        4.00            broken clouds
# 1           100        6.93               light rain
# 2            20        5.99               few clouds
# 3           100        1.86          overcast clouds
# 4            67        9.84            broken clouds
# ..          ...         ...                      ...
# 691          54        7.14            broken clouds
# 692          99        2.44          overcast clouds
# 693         100       16.11  light intensity drizzle
# 694          99        6.26               light rain
# 695          17        8.05               few clouds
#
# [696 rows x 10 columns]

# %%
city_data_df.head()
# Out:
#    Unnamed: 0          City Country      Lat       Lng  Max Temp  Humidity  \
# 0           0         Kapaa      US  22.0752 -159.3190     80.58        81
# 1           1  Punta Arenas      CL -53.1500  -70.9167     42.12        93
# 2           2     Cape Town      ZA -33.9258   18.4232     58.91        73
# 3           3       Aksarka      RU  66.5606   67.7975      3.36        95
# 4           4         Hobyo      SO   5.3505   48.5268     83.25        72
#
#    Cloudiness  Wind Speed Current Description
# 0          59        4.00       broken clouds
# 1         100        6.93          light rain
# 2          20        5.99          few clouds
# 3         100        1.86     overcast clouds
# 4          67        9.84       broken clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input("What is the minimum temperature you would like for your trip?")) 
max_temp = float(input("What is the maximum temperature you would like for your trip?"))
# Out:
# What is the minimum temperature you would like for your trip?75
# What is the maximum temperature you would like for your trip?90

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
preferred_cities_df = city_data_df.loc[(city_data_df["Max Temp"] <= max_temp) & \
                                       (city_data_df["Max Temp"] >= min_temp)]

preferred_cities_df.head(10)
# Out:
#     Unnamed: 0        City Country      Lat       Lng  Max Temp  Humidity  \
# 0            0       Kapaa      US  22.0752 -159.3190     80.58        81
# 4            4       Hobyo      SO   5.3505   48.5268     83.25        72
# 10          10       Mabay      PH   6.0577  124.4666     84.15        76
# 11          11    Buctzotz      MX  21.2000  -88.7833     82.69        54
# 12          12     Rikitea      PF -23.1203 -134.9692     75.33        77
# 20          20   Namatanai      PG  -3.6667  152.4333     85.69        62
# 22          22  Butaritari      KI   3.0707  172.7902     81.52        77
# 23          23       Bajil      YE  15.0584   43.2851     81.52        70
# 27          27       Vaini      TO -21.2000 -175.2000     77.92        69
# 29          29     Bubaque      GW  11.2833  -15.8333     76.55        78
#
#     Cloudiness  Wind Speed Current Description
# 0           59        4.00       broken clouds
# 4           67        9.84       broken clouds
# 10          64        2.77       moderate rain
# 11          82       11.14       broken clouds
# 12         100       15.55       moderate rain
# 20          90        5.95     overcast clouds
# 22          54       13.91       broken clouds
# 23           8        1.97           clear sky
# 27         100        3.13     overcast clouds
# 29          13       13.09          few clouds

# %%
preferred_cities2 = preferred_cities.reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/6m/01mj9dzd6x59p4btj06jwhw40000gn/T/ipykernel_3928/801487321.py in <module>
# ----> 1 preferred_cities2 = preferred_cities.reset_index(drop=True)
#
# NameError: name 'preferred_cities' is not defined

# %%
# 4a. Determine if there are any empty rows.
preferred_cities_df.count()
# Out:
# Unnamed: 0             207
# City                   207
# Country                207
# Lat                    207
# Lng                    207
# Max Temp               207
# Humidity               207
# Cloudiness             207
# Wind Speed             207
# Current Description    207
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#           City Country  Max Temp Current Description      Lat       Lng  \
# 0        Kapaa      US     80.58       broken clouds  22.0752 -159.3190
# 4        Hobyo      SO     83.25       broken clouds   5.3505   48.5268
# 10       Mabay      PH     84.15       moderate rain   6.0577  124.4666
# 11    Buctzotz      MX     82.69       broken clouds  21.2000  -88.7833
# 12     Rikitea      PF     75.33       moderate rain -23.1203 -134.9692
# 20   Namatanai      PG     85.69     overcast clouds  -3.6667  152.4333
# 22  Butaritari      KI     81.52       broken clouds   3.0707  172.7902
# 23       Bajil      YE     81.52           clear sky  15.0584   43.2851
# 27       Vaini      TO     77.92     overcast clouds -21.2000 -175.2000
# 29     Bubaque      GW     76.55          few clouds  11.2833  -15.8333
#
#    Hotel Name
# 0
# 4
# 10
# 11
# 12
# 20
# 22
# 23
# 27
# 29

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": G_API_Key
}


# 6b. Iterate through the hotel DataFrame.

for index, row in hotel_df.iterrows():
 # 6c. Get latitude and longitude from DataFrame    lat = row["Lat"]
    lat = row["Lat"]
    lng = row["Lng"]
    params["location"]=f"{lat},{lng}"

    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    hotels = requests.get(base_url, params=params).json()

    # 6e. Make request and retrieve the JSON data from the search. 
    #hotel_df = requests.get(base_url, params=params).json()
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.
# Hotel not found... skipping.

# %%
hotel_df.head(10)
# Out:
#           City Country  Max Temp Current Description      Lat       Lng  \
# 0        Kapaa      US     80.58       broken clouds  22.0752 -159.3190
# 4        Hobyo      SO     83.25       broken clouds   5.3505   48.5268
# 10       Mabay      PH     84.15       moderate rain   6.0577  124.4666
# 11    Buctzotz      MX     82.69       broken clouds  21.2000  -88.7833
# 12     Rikitea      PF     75.33       moderate rain -23.1203 -134.9692
# 20   Namatanai      PG     85.69     overcast clouds  -3.6667  152.4333
# 22  Butaritari      KI     81.52       broken clouds   3.0707  172.7902
# 23       Bajil      YE     81.52           clear sky  15.0584   43.2851
# 27       Vaini      TO     77.92     overcast clouds -21.2000 -175.2000
# 29     Bubaque      GW     76.55          few clouds  11.2833  -15.8333
#
#                              Hotel Name
# 0   Sheraton Kauai Coconut Beach Resort
# 4                     Iftin hotel hobyo
# 10               Bautista Lodging House
# 11                             Buctoztz
# 12                      People ThankYou
# 20                Seagulls Inn Namatani
# 22                   Isles Sunset Lodge
# 23                          فندق حضرموت
# 27                  Keleti Beach Resort
# 29                   Casa Dora, Bubaque

# %%
# 7. Drop the rows where there is no Hotel Name.

# %%
clean_hotel_df = hotel_df.replace(r'^\s*$', np.nan, regex=True)

# %%
clean_hotel_df = clean_hotel_df.dropna()

# %%
# 8a. Create the output File (CSV)
output_data_file = "WeatherPy_Vacation.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Weather Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>

"""
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]

# %%
# 11a. Add a marker layer for each city to the map. 

locations = hotel_df[["Lat", "Lng"]]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)

marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
# Call the figure to plot the data.

fig.add_layer(marker_layer)


# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
